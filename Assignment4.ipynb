# %% [markdown]
# ## ASSIGNMENT 4 ##

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv('winequality-red.csv')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df.shape
# Out:
# (1599, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df.quality.value_counts()
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %% [markdown]
# 3. Visualization

# %% [markdown]
# ***Univariate analysis***

# %%
sns.countplot(data=df, x="quality")
# Out:
# <AxesSubplot: xlabel='quality', ylabel='count'>

# %%
sns.displot(data=df, x="alcohol")

# %% [markdown]
# ***Bivariate analysis***

# %%
sns.barplot(data = df, x="quality", y="fixed acidity")
# Out:
# <AxesSubplot: xlabel='quality', ylabel='fixed acidity'>

# %%
sns.barplot(data = df, x="quality", y="volatile acidity")
# Out:
# <AxesSubplot: xlabel='quality', ylabel='volatile acidity'>

# %%
sns.barplot(data = df, x="quality", y="citric acid")
# Out:
# <AxesSubplot: xlabel='quality', ylabel='citric acid'>

# %% [markdown]
# ***Multivariate analysis***

# %%
sns.pairplot(data=df)

# %%
plt.figure(figsize=(11,9))
sns.heatmap(data=df.corr(),annot=True)
# Out:
# <AxesSubplot: >

# %% [markdown]
# 4. Perform descriptive statistics on the dataset.

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %% [markdown]
# 5. Check for Missing values and deal with them.

# %%
df.isnull().any()
# Out:
# fixed acidity           False
# volatile acidity        False
# citric acid             False
# residual sugar          False
# chlorides               False
# free sulfur dioxide     False
# total sulfur dioxide    False
# density                 False
# pH                      False
# sulphates               False
# alcohol                 False
# quality                 False
# dtype: bool

# %% [markdown]
# 6. Find the outliers and replace them

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
numeric_columns = ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
       'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
       'pH', 'sulphates', 'alcohol']

for col in numeric_columns:
    sns.boxplot(x=df[col])
    plt.title(f'Box Plot for {col}')
    plt.show()

# %%
df.median()
# Out:
# fixed acidity            7.90000
# volatile acidity         0.52000
# citric acid              0.26000
# residual sugar           2.20000
# chlorides                0.07900
# free sulfur dioxide     14.00000
# total sulfur dioxide    38.00000
# density                  0.99675
# pH                       3.31000
# sulphates                0.62000
# alcohol                 10.20000
# quality                  6.00000
# dtype: float64

# %%
for attri in numeric_columns:
    q1 = df[attri].quantile(0.25)  # Q1
    q3 = df[attri].quantile(0.75)  # Q3
    IQR = q3 - q1
    upper_limit = q3 + 1.5 * IQR
    lower_limit = q1 - 1.5 * IQR

    # Replace values outside the upper or lower limit with the median
    df[attri] = np.where((df[attri] > upper_limit) | (df[attri] < lower_limit), df[attri].median(), df[attri])

# %%
for i in numeric_columns:
    
    sns.boxplot(x=df[i])
    plt.title(f'Box Plot for {i}')
    plt.show()

# %%
df["quality"] = np.where(df["quality"] > 5, 1, 0)

# %%
df['quality'].value_counts()
# Out:
# 1    855
# 0    744
# Name: quality, dtype: int64

# %%
X = df.drop("quality", axis=1)
y = df["quality"]

# %% [markdown]
# 10. Scaling the data

# %%
from sklearn.preprocessing import MinMaxScaler
scale =MinMaxScaler()

# %%
X_scaled= pd.DataFrame(scale.fit_transform(X),columns =X.columns)
X_scaled.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0       0.363636          0.651685     0.000000        0.363636   0.448718
# 1       0.415584          0.853933     0.000000        0.618182   0.730769
# 2       0.415584          0.719101     0.050633        0.509091   0.653846
# 3       0.857143          0.179775     0.708861        0.363636   0.435897
# 4       0.363636          0.651685     0.000000        0.363636   0.448718
#
#    free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# 0             0.243902              0.241379  0.630058  0.773333   0.348485
# 1             0.585366              0.525862  0.514451  0.360000   0.530303
# 2             0.341463              0.413793  0.537572  0.440000   0.484848
# 3             0.390244              0.465517  0.653179  0.306667   0.378788
# 4             0.243902              0.241379  0.630058  0.773333   0.348485
#
#     alcohol
# 0  0.196078
# 1  0.274510
# 2  0.274510
# ...

# %% [markdown]
# 11. Split the data into training and testing

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X_scaled,y,test_size=0.3,random_state=10,stratify=y)

# %% [markdown]
# 12.check the training and testing data shape.

# %%
print('X_train shape',X_train.shape)
print('X_test shape',X_test.shape)
print('y_train shape',y_train.shape)
print('y_test shape',y_test.shape)
# Out:
# X_train shape (1119, 11)
# X_test shape (480, 11)
# y_train shape (1119,)
# y_test shape (480,)

# %%
y_train.value_counts()
# Out:
# 1    598
# 0    521
# Name: quality, dtype: int64

# %%
y_test.value_counts()
# Out:
# 1    257
# 0    223
# Name: quality, dtype: int64

# %%
X_test.head()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1025       0.519481          0.797753     0.000000        0.690909   0.692308
# 899        0.480519          0.449438     0.025316        0.909091   0.551282
# 1568       0.311688          0.494382     0.164557        0.254545   0.461538
# 1031       0.350649          0.483146     0.012658        0.327273   0.666667
# 579        0.779221          0.213483     0.620253        0.472727   0.282051
#
#       free sulfur dioxide  total sulfur dioxide   density        pH  \
# 1025             0.390244              0.318966  0.678613  0.533333
# 899              0.121951              0.043103  0.759538  0.733333
# 1568             0.585366              0.310345  0.455491  0.546667
# 1031             0.195122              0.077586  0.322543  0.560000
# 579              0.414634              0.293103  0.606936  0.280000
#
#       sulphates   alcohol
# 1025   0.409091  0.392157
# 899    0.242424  0.509804
# ...

# %%
from sklearn.linear_model import LogisticRegression 
from sklearn import metrics
model1 = LogisticRegression()
model1.fit(X_train, y_train)
prediction = model1.predict(X_test)
print('Accuracy:',metrics.accuracy_score(prediction,y_test))
# Out:
# Accuracy: 0.7125

# %%
from sklearn.metrics import confusion_matrix,classification_report
confusion_mat = confusion_matrix(y_test,prediction)
print("Confusion matrix: \n",confusion_mat)
print(classification_report(y_test,prediction))
# Out:
# Confusion matrix:
#  [[159  64]
#  [ 74 183]]
#               precision    recall  f1-score   support
#
#            0       0.68      0.71      0.70       223
#            1       0.74      0.71      0.73       257
#
#     accuracy                           0.71       480
#    macro avg       0.71      0.71      0.71       480
# weighted avg       0.71      0.71      0.71       480

# %%
#Using KNN Neighbors
from sklearn.neighbors import KNeighborsClassifier
model2 = KNeighborsClassifier(n_neighbors=5)
model2.fit(X_train,y_train)
y_pred2 = model2.predict(X_test)

from sklearn.metrics import accuracy_score
print("Accuracy Score:",accuracy_score(y_test,y_pred2))
# Out:
# Accuracy Score: 0.7020833333333333

# %%
from sklearn.metrics import confusion_matrix,classification_report
confusion_mat = confusion_matrix(y_test,y_pred2)
print("Confusion matrix: \n",confusion_mat)
print(classification_report(y_test,y_pred2))
# Out:
# Confusion matrix:
#  [[145  78]
#  [ 65 192]]
#               precision    recall  f1-score   support
#
#            0       0.69      0.65      0.67       223
#            1       0.71      0.75      0.73       257
#
#     accuracy                           0.70       480
#    macro avg       0.70      0.70      0.70       480
# weighted avg       0.70      0.70      0.70       480

# %%
#Using GaussianNB
from sklearn.naive_bayes import GaussianNB
model3 = GaussianNB()
model3.fit(X_train,y_train)
y_pred3 = model3.predict(X_test)

from sklearn.metrics import accuracy_score
print("Accuracy Score:",accuracy_score(y_test,y_pred3))
# Out:
# Accuracy Score: 0.71875

# %%
from sklearn.metrics import confusion_matrix,classification_report
confusion_mat = confusion_matrix(y_test,y_pred3)
print("Confusion matrix: \n",confusion_mat)
print(classification_report(y_test, y_pred3))
# Out:
# Confusion matrix:
#  [[167  56]
#  [ 79 178]]
#               precision    recall  f1-score   support
#
#            0       0.68      0.75      0.71       223
#            1       0.76      0.69      0.73       257
#
#     accuracy                           0.72       480
#    macro avg       0.72      0.72      0.72       480
# weighted avg       0.72      0.72      0.72       480

# %%
from sklearn.tree import DecisionTreeClassifier

model4 = DecisionTreeClassifier(criterion='entropy',random_state=7)
model4.fit(X_train,y_train)
y_pred4 = model4.predict(X_test)

from sklearn.metrics import accuracy_score
print("Accuracy Score:",accuracy_score(y_test,y_pred4))
# Out:
# Accuracy Score: 0.73125

# %%
from sklearn.metrics import confusion_matrix,classification_report
confusion_mat = confusion_matrix(y_test,y_pred4)
print("Confusion matrix: \n",confusion_mat)
print(classification_report(y_test,y_pred4))
# Out:
# Confusion matrix:
#  [[152  71]
#  [ 58 199]]
#               precision    recall  f1-score   support
#
#            0       0.72      0.68      0.70       223
#            1       0.74      0.77      0.76       257
#
#     accuracy                           0.73       480
#    macro avg       0.73      0.73      0.73       480
# weighted avg       0.73      0.73      0.73       480

# %%
ans = model4.predict([[0.1,0.3,0.2,0.4,0.6,0.67,0.54,0.98,0.76,0.98,0.88]])
# Out:
# c:\Users\SIMRAN\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
print(ans)
# Out:
# [1]

# %%
ans = model1.predict([[0.1,0.3,0.2,0.4,0.6,0.67,0.54,0.98,0.76,0.98,0.88]])
ans
# Out:
# c:\Users\SIMRAN\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1])

# %%
ans = model3.predict([[0.0,0.0,0.0,0.4,0.6,0.0,0.4,0.8,0.0,0.0,0.0]])
ans
# Out:
# c:\Users\SIMRAN\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(
# array([0])
